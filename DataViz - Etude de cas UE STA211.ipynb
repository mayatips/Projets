# %%
import pandas as pd, numpy as np, calendar as cal, datetime as dt, matplotlib.pyplot as plt

# %%
df_file = pd.read_table("DATA/positionshistoriqueW.csv",sep =';',header = 0, parse_dates=[1,2])

# %%
df_10004 = pd.read_table("DATA/positionshistoriqueW_10004.csv",sep =';',header = 0, parse_dates=[1,2])

# %%
df_sans_10004 = pd.read_table("DATA/positionshistoriqueW_SANS10004.csv",sep =';',header = 0, parse_dates=[1,2])

# %%
df_10004.shape
# Out:
# (10042, 18)

# %%
df_sans_10004.shape
# Out:
# (156266, 18)

# %%
df_file.columns
# Out:
# Index(['DateReception_HeureReception', 'DateGPS_HeureGPS', 'idBalise',
#        'Longitude', 'Latitude', 'Vitesse', 'Direction', 'Altitude',
#        'Satellites', 'MessageId', 'Puissance', 'VoltageBatterie', 'Distance',
#        'DayWeekGPS', 'DayWeekRec', 'NumDateGPS', 'NumDateRec',
#        'DelaiTransmission'],
#       dtype='object')

# %%
df=df_sans_10004[df_sans_10004['NumDateRec'] <150000]
#df=df_file
df.shape
# Out:
# (13865, 18)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(column='DelaiTransmission')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f43bec15278>]], dtype=object)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df_10004.hist(column='DelaiTransmission')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f43bdfd5fd0>]], dtype=object)

# %%
df.DelaiTransmission.plot.kde()

# %%
df[df['DayWeekRec']>5].shape
# Out:
# (0, 18)

# %%
df.boxplot(column='DelaiTransmission' ,by='idBalise', showfliers=False)
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d849fce01d2> in <module>()
# ----> 1 df.boxplot(column='MessageId' ,by='idBalise', showfliers=False)
#       2 plt.xticks(rotation=90)
#
# NameError: name 'df' is not defined

# %%
df=df_sans_10004[df_sans_10004['NumDateGPS']<390000]
x = df['Vitesse']
y = df['DelaiTransmission']

plt.scatter(x,y,s=10)

plt.title('Nuage de points avec Matplotlib')
plt.xlabel('x')
plt.ylabel('y')
plt.savefig('ScatterPlot.png')

plt.xticks(rotation=45)
plt.show()

# %%
df=df_sans_10004[df_sans_10004['NumDateGPS']<390000]
x = df['Latitude']
y = df['DelaiTransmission']
z = df['Longitude']
plt.scatter(z,y,s=10)

plt.title('Nuage de points avec Matplotlib')
plt.xlabel('x')
plt.ylabel('y')

plt.savefig('ScatterPlot.png')
plt.show()

# %%
x = df['Longitude']
y = df['Latitude']

plt.scatter(x,y,s=1)

plt.title('Nuage de points avec Matplotlib')
plt.xlabel('x')
plt.ylabel('y')
plt.savefig('ScatterPlot.png')
plt.show()

# %%
x2 = df[df['DelaiTransmission']>3600].idBalise

# %%
x2.shape
# Out:
# (17,)

# %%
y2 = df[(df['DelaiTransmission']>3600)].DelaiTransmission

# %%
y2.shape
# Out:
# (17,)

# %%
plt.scatter(x2,y2,s=10)

plt.title('Nuage de points avec Matplotlib')
plt.xlabel('x')
plt.ylabel('y')
plt.savefig('ScatterPlot.png')
plt.xticks(rotation=90)
plt.show()

# %%
# VARIABLE QUANTITATIVE

# Histogramme plus beau

df[df.DelaiTransmission>3600]["DelaiTransmission"].hist(normed=True,bins=10)

plt.show()
